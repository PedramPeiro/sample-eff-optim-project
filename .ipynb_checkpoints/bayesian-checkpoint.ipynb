# %%
import numpy as np
import os

# %%
SUMO_HOME="/usr/local/opt/sumo/share/sumo"
PATH=SUMO_HOME+"/tools"
intersection=3

seed=1

prefix="test"

sim_net=f"{intersection}intersections.net.xml"

additional_file="additional.xml"

# %%
! python3 {PATH}/randomTrips.py \
-n {sim_net} \
-r {prefix}.rou.xml \
-e 100 \
-s {seed}
# Out:
# Success.

# %%
#cycle times and green times for the 3 intersections
cycle_time=[90,90,90]
green_time=[20,25,28]


cycle_time_1=cycle_time[0]
cycle_time_2=cycle_time[1]
cycle_time_3=cycle_time[2]

green_time_1=green_time[0]
green_time_2=green_time[1]
green_time_3=green_time[2]

# %%
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <!-- generated on 2024-07-11 19:58:20 by Eclipse SUMO netedit Version 1.20.0
# <configuration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/neteditConfiguration.xsd">
#
#     <input>
#         <sumo-net-file value="/Users/jiaqiyu/Documents/Research 2024/3intersections.net.xml"/>
#     </input>
#
#     <output>
#         <output-file value="/Users/jiaqiyu/Documents/Research 2024/3intersections.net.xml"/>
#     </output>
#
#     <processing>
#         <offset.disable-normalization value="true"/>
#     </processing>
#
#     <junctions>
#         <no-turnarounds value="true"/>
#     </junctions>
#
#     <netedit>
#         <new-network value="false"/>
#     </netedit>
#
# </configuration>
# -->
#
# ...

# %%
# Run SUMO to generate outputs for Ground Truth averaged over 20 repetition

for rep in range(0,20,1):

    net_str=f"""<?xml version="1.0" encoding="UTF-8"?>

<!-- generated on 2024-07-11 19:58:20 by Eclipse SUMO netedit Version 1.20.0
<configuration xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/neteditConfiguration.xsd">

    <input>
        <sumo-net-file value="/Users/jiaqiyu/Documents/Research 2024/3intersections.net.xml"/>
    </input>

    <output>
        <output-file value="/Users/jiaqiyu/Documents/Research 2024/3intersections.net.xml"/>
    </output>

    <processing>
        <offset.disable-normalization value="true"/>
    </processing>

    <junctions>
        <no-turnarounds value="true"/>
    </junctions>

    <netedit>
        <new-network value="false"/>
    </netedit>

</configuration>
-->

<net version="1.20" junctionCornerDetail="5" limitTurnSpeed="5.50" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/net_file.xsd">

    <location netOffset="0.00,0.00" convBoundary="-69.54,-19.08,118.71,73.15" origBoundary="10000000000.00,10000000000.00,-10000000000.00,-10000000000.00" projParameter="!"/>

    <edge id=":J1_0" function="internal">
        <lane id=":J1_0_0" index="0" speed="6.48" length="9.03" shape="-22.09,29.26 -22.47,26.81 -23.55,25.07 -25.31,24.06 -27.77,23.76"/>
    </edge>
    <edge id=":J1_1" function="internal">
        <lane id=":J1_1_0" index="0" speed="13.89" length="14.52" shape="-22.09,29.26 -22.08,14.74"/>
    </edge>
    <edge id=":J1_2" function="internal">
        <lane id=":J1_2_0" index="0" speed="7.98" length="4.17" shape="-22.09,29.26 -21.58,25.38 -21.45,25.16"/>
    </edge>
    <edge id=":J1_12" function="internal">
        <lane id=":J1_12_0" index="0" speed="7.98" length="10.07" shape="-21.45,25.16 -19.95,22.62 -17.20,20.96 -13.33,20.40"/>
    </edge>
    <edge id=":J1_3" function="internal">
        <lane id=":J1_3_0" index="0" speed="6.48" length="9.04" shape="-13.33,23.60 -15.79,23.95 -17.54,25.01 -18.57,26.76 -18.89,29.22"/>
        <lane id="28_0" index="0" speed="13.89" length="31.61" shape="31.30,14.67 31.96,-16.93"/>
    </edge>
    <edge id="310" from="J3" to="J10" priority="-1">
        <lane id="310_0" index="0" speed="13.89" length="26.19" shape="92.49,19.68 118.67,19.04"/>
    </edge>
    <edge id="32" from="J3" to="J2" priority="-1">
        <lane id="32_0" index="0" speed="13.89" length="38.04" shape="78.10,23.13 40.06,23.53"/>
    </edge>
    <edge id="36" from="J3" to="J6" priority="-1">
        <lane id="36_0" index="0" speed="13.89" length="43.39" shape="87.12,28.64 88.75,72.00"/>
    </edge>
    <edge id="39" from="J3" to="J9" priority="-1">
        <lane id="39_0" index="0" speed="13.89" length="33.26" shape="83.65,14.18 83.65,-19.08"/>
    </edge>
    <edge id="41" from="J4" to="J1" priority="-1">
        <lane id="41_0" index="0" speed="13.89" length="40.65" shape="-21.63,69.90 -22.09,29.26"/>
    </edge>
    <edge id="52" from="J5" to="J2" priority="-1">
        <lane id="52_0" index="0" speed="13.89" length="43.94" shape="31.15,73.15 31.15,29.20"/>
    </edge>
    <edge id="63" from="J6" to="J3" priority="-1">
        <lane id="63_0" index="0" speed="13.89" length="43.39" shape="85.56,72.12 83.92,28.76"/>
    </edge>
    <edge id="71" from="J7" to="J1" priority="-1">
        <lane id="71_0" index="0" speed="13.89" length="32.48" shape="-18.43,-17.69 -18.88,14.78"/>
    </edge>
    <edge id="82" from="J8" to="J2" priority="-1">
        <lane id="82_0" index="0" speed="13.89" length="31.61" shape="35.16,-16.87 34.50,14.74"/>
    </edge>
    <edge id="93" from="J9" to="J3" priority="-1">
        <lane id="93_0" index="0" speed="13.89" length="33.26" shape="86.85,-19.08 86.85,14.18"/>
    </edge>

    <tlLogic id="J1" type="static" programID="0" offset="0">
        <phase duration="{green_time_1}" state="rrrGGgrrrGGg"/>
        <phase duration="2"  state="rrryyyrrryyy"/>
        <phase duration="{60-green_time_1-4}" state="GGgrrrGGgrrr"/>
        <phase duration="2"  state="yyyrrryyyrrr"/>
    </tlLogic>
    <tlLogic id="J2" type="static" programID="0" offset="0">
        <phase duration="{green_time_2}" state="rrrGGgrrrGGg"/>
        <phase duration="2"  state="rrryyyrrryyy"/>
        <phase duration="{60-green_time_2-4}" state="GGgrrrGGgrrr"/>
        <phase duration="2"  state="yyyrrryyyrrr"/>
    </tlLogic>
    <tlLogic id="J3" type="static" programID="0" offset="0">
        <phase duration="{green_time_3}" state="rrrGGgrrrGGg"/>
        <phase duration="2"  state="rrryyyrrryyy"/>
        <phase duration="{60-green_time_3-4}" state="GGgrrrGGgrrr"/>
        <phase duration="2"  state="yyyrrryyyrrr"/>
    </tlLogic>

    <junction id="J0" type="dead_end" x="-69.54" y="23.09" incLanes="10_0" intLanes="" shape="-69.54,23.09 -69.47,26.29 -69.54,23.09"/>
    <junction id="J1" type="traffic_light" x="-20.58" y="22.00" incLanes="41_0 21_0 71_0 01_0" intLanes=":J1_0_0 :J1_1_0 :J1_12_0 :J1_3_0 :J1_4_0 :J1_13_0 :J1_6_0 :J1_7_0 :J1_14_0 :J1_9_0 :J1_10_0 :J1_15_0" shape="-23.69,29.28 -17.29,29.20 -16.87,26.98 -16.33,26.20 -15.55,25.65 -14.55,25.31 -13.33,25.20 -13.33,18.80 -15.55,18.36 -16.32,17.80 -16.86,17.02 -17.18,16.03 -17.28,14.80 -23.68,14.72 -24.17,17.03 -24.76,17.86 -25.57,18.45 -26.61,18.82 -27.88,18.96 -27.74,25.36 -25.51,25.76 -24.73,26.30 -24.16,27.06 -23.82,28.05">
        <request index="0"  response="000000010000" foes="000100010000" cont="0"/>
        <request index="1"  response="111000110000" foes="111100110000" cont="0"/>
        <request index="2"  response="110111110000" foes="110111110000" cont="1"/>
        <request index="3"  response="000000000000" foes="100010000000" cont="0"/>
        <request index="4"  response="000100000100" foes="100110000111" cont="0"/>
        <request index="5"  response="011100000100" foes="111110000110" cont="1"/>
        <request index="6"  response="010000000000" foes="010000000100" cont="0"/>
        <request index="7"  response="110000111000" foes="110000111100" cont="0"/>
        <request index="8"  response="110000110011" foes="110000110111" cont="1"/>
        <request index="9"  response="000000000000" foes="000000100010" cont="0"/>
        <request index="10" response="000100000100" foes="000111100110" cont="0"/>
        <request index="11" response="000100111100" foes="000110111110" cont="1"/>
    </junction>
    <junction id="J10" type="dead_end" x="118.71" y="20.64" incLanes="310_0" intLanes="" shape="118.71,20.64 118.63,17.44 118.71,20.64"/>
    <junction id="J2" type="traffic_light" x="32.75" y="22.00" incLanes="52_0 32_0 82_0 12_0" intLanes=":J2_0_0 :J2_1_0 :J2_12_0 :J2_3_0 :J2_4_0 :J2_13_0 :J2_6_0 :J2_7_0 :J2_14_0 :J2_9_0 :J2_10_0 :J2_15_0" shape="29.55,29.20 35.95,29.20 36.40,26.96 36.98,26.17 37.78,25.60 38.82,25.25 40.08,25.13 40.01,18.73 37.80,18.31 37.03,17.76 36.50,16.99 36.18,15.99 36.10,14.77 29.70,14.64 29.20,16.95 28.62,17.76 27.81,18.34 26.79,18.69 25.55,18.80 25.55,25.20 27.77,25.65 28.55,26.20 29.10,26.98 29.43,27.98">
        <request index="0"  response="000000010000" foes="000100010000" cont="0"/>
        <request index="1"  response="111000110000" foes="111100110000" cont="0"/>
        <request index="2"  response="110111110000" foes="110111110000" cont="1"/>
        <request index="3"  response="000000000000" foes="100010000000" cont="0"/>
        <request index="4"  response="000100000100" foes="100110000111" cont="0"/>
        <request index="5"  response="011100000100" foes="111110000110" cont="1"/>
        <request index="6"  response="010000000000" foes="010000000100" cont="0"/>
        <request index="7"  response="110000111000" foes="110000111100" cont="0"/>
        <request index="8"  response="110000110011" foes="110000110111" cont="1"/>
        <request index="9"  response="000000000000" foes="000000100010" cont="0"/>
        <request index="10" response="000100000100" foes="000111100110" cont="0"/>
        <request index="11" response="000100111100" foes="000110111110" cont="1"/>
    </junction>
    <junction id="J3" type="traffic_light" x="85.25" y="21.46" incLanes="63_0 103_0 93_0 23_0" intLanes=":J3_0_0 :J3_1_0 :J3_12_0 :J3_3_0 :J3_4_0 :J3_13_0 :J3_6_0 :J3_7_0 :J3_14_0 :J3_9_0 :J3_10_0 :J3_15_0" shape="82.32,28.82 88.72,28.58 89.08,26.34 89.62,25.55 90.38,24.98 91.38,24.62 92.60,24.48 92.45,18.08 90.23,17.69 89.45,17.16 88.89,16.39 88.56,15.40 88.45,14.18 82.05,14.18 81.61,16.47 81.05,17.27 80.27,17.85 79.27,18.21 78.05,18.33 78.12,24.73 80.39,25.17 81.19,25.73 81.79,26.53 82.16,27.56">
        <request index="0"  response="000000010000" foes="000100010000" cont="0"/>
        <request index="1"  response="111000110000" foes="111100110000" cont="0"/>
        <request index="2"  response="110111110000" foes="110111110000" cont="1"/>
        <request index="3"  response="000000000000" foes="100010000000" cont="0"/>
        <request index="4"  response="000100000100" foes="100110000111" cont="0"/>
        <request index="5"  response="111100000100" foes="111110000110" cont="1"/>
        <request index="6"  response="010000000000" foes="010000000100" cont="0"/>
        <request index="7"  response="110000111000" foes="110000111100" cont="0"/>
        <request index="8"  response="110000110011" foes="110000110111" cont="1"/>
        <request index="9"  response="000000000000" foes="000000100010" cont="0"/>
        <request index="10" response="000100000100" foes="000111100110" cont="0"/>
        <request index="11" response="000100011100" foes="000110111110" cont="1"/>
    </junction>
    <junction id="J4" type="dead_end" x="-20.03" y="69.88" incLanes="14_0" intLanes="" shape="-20.03,69.88 -16.83,69.85 -20.03,69.88"/>
    <junction id="J5" type="dead_end" x="32.75" y="73.15" incLanes="25_0" intLanes="" shape="32.75,73.15 35.95,73.15 32.75,73.15"/>
    <junction id="J6" type="dead_end" x="87.15" y="72.06" incLanes="36_0" intLanes="" shape="87.15,72.06 90.35,71.94 87.15,72.06"/>
    <junction id="J7" type="dead_end" x="-20.03" y="-17.72" incLanes="17_0" intLanes="" shape="-20.03,-17.72 -23.23,-17.76 -20.03,-17.72"/>
    <junction id="J8" type="dead_end" x="33.56" y="-16.90" incLanes="28_0" intLanes="" shape="33.56,-16.90 30.36,-16.97 33.56,-16.90"/>
    <junction id="J9" type="dead_end" x="85.25" y="-19.08" incLanes="39_0" intLanes="" shape="85.25,-19.08 82.05,-19.08 85.25,-19.08"/>

    <junction id=":J1_12_0" type="internal" x="-21.45" y="25.16" incLanes=":J1_2_0 71_0" intLanes=":J1_4_0 :J1_5_0 :J1_6_0 :J1_7_0 :J1_10_0 :J1_11_0"/>
    <junction id=":J1_13_0" type="internal" x="-17.20" y="23.05" incLanes=":J1_5_0 01_0" intLanes=":J1_1_0 :J1_2_0 :J1_7_0 :J1_8_0 :J1_9_0 :J1_10_0"/>
    <junction id=":J1_14_0" type="internal" x="-19.48" y="18.64" incLanes=":J1_8_0 41_0" intLanes=":J1_0_0 :J1_1_0 :J1_4_0 :J1_5_0 :J1_10_0 :J1_11_0"/>
    <junction id=":J1_15_0" type="internal" x="-23.75" y="21.16" incLanes=":J1_11_0 21_0" intLanes=":J1_1_0 :J1_2_0 :J1_3_0 :J1_4_0 :J1_7_0 :J1_8_0"/>
    <junction id=":J2_12_0" type="internal" x="31.83" y="25.14" incLanes=":J2_2_0 82_0" intLanes=":J2_4_0 :J2_5_0 :J2_6_0 :J2_7_0 :J2_10_0 :J2_11_0"/>
    <junction id=":J2_13_0" type="internal" x="35.99" y="22.91" incLanes=":J2_5_0 12_0" intLanes=":J2_1_0 :J2_2_0 :J2_7_0 :J2_8_0 :J2_9_0 :J2_10_0"/>
    <junction id=":J2_14_0" type="internal" x="33.81" y="18.71" incLanes=":J2_8_0 52_0" intLanes=":J2_0_0 :J2_1_0 :J2_4_0 :J2_5_0 :J2_10_0 :J2_11_0"/>
    <junction id=":J2_15_0" type="internal" x="29.51" y="21.02" incLanes=":J2_11_0 32_0" intLanes=":J2_1_0 :J2_2_0 :J2_3_0 :J2_4_0 :J2_7_0 :J2_8_0"/>
    <junction id=":J3_12_0" type="internal" x="84.48" y="24.60" incLanes=":J3_2_0 93_0" intLanes=":J3_4_0 :J3_5_0 :J3_6_0 :J3_7_0 :J3_10_0 :J3_11_0"/>
    <junction id=":J3_13_0" type="internal" x="88.48" y="22.31" incLanes=":J3_5_0 23_0" intLanes=":J3_1_0 :J3_2_0 :J3_7_0 :J3_8_0 :J3_9_0 :J3_10_0"/>
    <junction id=":J3_14_0" type="internal" x="86.30" y="18.06" incLanes=":J3_8_0 63_0" intLanes=":J3_0_0 :J3_1_0 :J3_4_0 :J3_5_0 :J3_10_0 :J3_11_0"/>
    <junction id=":J3_15_0" type="internal" x="82.02" y="20.51" incLanes=":J3_11_0 103_0" intLanes=":J3_1_0 :J3_2_0 :J3_3_0 :J3_4_0 :J3_7_0 :J3_8_0"/>

    <connection from="01" to="17" fromLane="0" toLane="0" via=":J1_9_0" tl="J1" linkIndex="9" dir="r" state="O"/>
    <connection from="01" to="12" fromLane="0" toLane="0" via=":J1_10_0" tl="J1" linkIndex="10" dir="s" state="O"/>
    <connection from="01" to="14" fromLane="0" toLane="0" via=":J1_11_0" tl="J1" linkIndex="11" dir="l" state="o"/>
    <connection from="103" to="36" fromLane="0" toLane="0" via=":J3_3_0" tl="J3" linkIndex="3" dir="r" state="O"/>
    <connection from="103" to="32" fromLane="0" toLane="0" via=":J3_4_0" tl="J3" linkIndex="4" dir="s" state="O"/>
    <connection from="103" to="39" fromLane="0" toLane="0" via=":J3_5_0" tl="J3" linkIndex="5" dir="l" state="o"/>
    <connection from="12" to="28" fromLane="0" toLane="0" via=":J2_9_0" tl="J2" linkIndex="9" dir="r" state="O"/>
    <connection from="12" to="23" fromLane="0" toLane="0" via=":J2_10_0" tl="J2" linkIndex="10" dir="s" state="O"/>
    <connection from="12" to="25" fromLane="0" toLane="0" via=":J2_11_0" tl="J2" linkIndex="11" dir="l" state="o"/>
    <connection from="21" to="14" fromLane="0" toLane="0" via=":J1_3_0" tl="J1" linkIndex="3" dir="r" state="O"/>
    <connection from="21" to="10" fromLane="0" toLane="0" via=":J1_4_0" tl="J1" linkIndex="4" dir="s" state="O"/>
    <connection from="21" to="17" fromLane="0" toLane="0" via=":J1_5_0" tl="J1" linkIndex="5" dir="l" state="o"/>
    <connection from="23" to="39" fromLane="0" toLane="0" via=":J3_9_0" tl="J3" linkIndex="9" dir="r" state="O"/>
    <connection from="23" to="310" fromLane="0" toLane="0" via=":J3_10_0" tl="J3" linkIndex="10" dir="s" state="O"/>
    <connection from="23" to="36" fromLane="0" toLane="0" via=":J3_11_0" tl="J3" linkIndex="11" dir="l" state="o"/>
    <connection from="32" to="25" fromLane="0" toLane="0" via=":J2_3_0" tl="J2" linkIndex="3" dir="r" state="O"/>
    <connection from="32" to="21" fromLane="0" toLane="0" via=":J2_4_0" tl="J2" linkIndex="4" dir="s" state="O"/>
    <connection from="32" to="28" fromLane="0" toLane="0" via=":J2_5_0" tl="J2" linkIndex="5" dir="l" state="o"/>
    <connection from="41" to="10" fromLane="0" toLane="0" via=":J1_0_0" tl="J1" linkIndex="0" dir="r" state="o"/>
    <connection from="41" to="17" fromLane="0" toLane="0" via=":J1_1_0" tl="J1" linkIndex="1" dir="s" state="o"/>
    <connection from="41" to="12" fromLane="0" toLane="0" via=":J1_2_0" tl="J1" linkIndex="2" dir="l" state="o"/>
    <connection from="52" to="21" fromLane="0" toLane="0" via=":J2_0_0" tl="J2" linkIndex="0" dir="r" state="o"/>
    <connection from="52" to="28" fromLane="0" toLane="0" via=":J2_1_0" tl="J2" linkIndex="1" dir="s" state="o"/>
    <connection from="52" to="23" fromLane="0" toLane="0" via=":J2_2_0" tl="J2" linkIndex="2" dir="l" state="o"/>
    <connection from="63" to="32" fromLane="0" toLane="0" via=":J3_0_0" tl="J3" linkIndex="0" dir="r" state="o"/>
    <connection from="63" to="39" fromLane="0" toLane="0" via=":J3_1_0" tl="J3" linkIndex="1" dir="s" state="o"/>
    <connection from="63" to="310" fromLane="0" toLane="0" via=":J3_2_0" tl="J3" linkIndex="2" dir="l" state="o"/>
    <connection from="71" to="12" fromLane="0" toLane="0" via=":J1_6_0" tl="J1" linkIndex="6" dir="r" state="o"/>
    <connection from="71" to="14" fromLane="0" toLane="0" via=":J1_7_0" tl="J1" linkIndex="7" dir="s" state="o"/>
    <connection from="71" to="10" fromLane="0" toLane="0" via=":J1_8_0" tl="J1" linkIndex="8" dir="l" state="o"/>
    <connection from="82" to="23" fromLane="0" toLane="0" via=":J2_6_0" tl="J2" linkIndex="6" dir="r" state="o"/>
    <connection from="82" to="25" fromLane="0" toLane="0" via=":J2_7_0" tl="J2" linkIndex="7" dir="s" state="o"/>
    <connection from="82" to="21" fromLane="0" toLane="0" via=":J2_8_0" tl="J2" linkIndex="8" dir="l" state="o"/>
    <connection from="93" to="310" fromLane="0" toLane="0" via=":J3_6_0" tl="J3" linkIndex="6" dir="r" state="o"/>
    <connection from="93" to="36" fromLane="0" toLane="0" via=":J3_7_0" tl="J3" linkIndex="7" dir="s" state="o"/>
    <connection from="93" to="32" fromLane="0" toLane="0" via=":J3_8_0" tl="J3" linkIndex="8" dir="l" state="o"/>

    <connection from=":J1_0" to="10" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J1_1" to="17" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J1_2" to="12" fromLane="0" toLane="0" via=":J1_12_0" dir="l" state="m"/>
    <connection from=":J1_12" to="12" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J1_3" to="14" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J1_4" to="10" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J1_5" to="17" fromLane="0" toLane="0" via=":J1_13_0" dir="l" state="m"/>
    <connection from=":J1_13" to="17" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J1_6" to="12" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J1_7" to="14" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J1_8" to="10" fromLane="0" toLane="0" via=":J1_14_0" dir="l" state="m"/>
    <connection from=":J1_14" to="10" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J1_9" to="17" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J1_10" to="12" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J1_11" to="14" fromLane="0" toLane="0" via=":J1_15_0" dir="l" state="m"/>
    <connection from=":J1_15" to="14" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J2_0" to="21" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J2_1" to="28" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J2_2" to="23" fromLane="0" toLane="0" via=":J2_12_0" dir="l" state="m"/>
    <connection from=":J2_12" to="23" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J2_3" to="25" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J2_4" to="21" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J2_5" to="28" fromLane="0" toLane="0" via=":J2_13_0" dir="l" state="m"/>
    <connection from=":J2_13" to="28" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J2_6" to="23" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J2_7" to="25" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J2_8" to="21" fromLane="0" toLane="0" via=":J2_14_0" dir="l" state="m"/>
    <connection from=":J2_14" to="21" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J2_9" to="28" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J2_10" to="23" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J2_11" to="25" fromLane="0" toLane="0" via=":J2_15_0" dir="l" state="m"/>
    <connection from=":J2_15" to="25" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J3_0" to="32" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J3_1" to="39" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J3_2" to="310" fromLane="0" toLane="0" via=":J3_12_0" dir="l" state="m"/>
    <connection from=":J3_12" to="310" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J3_3" to="36" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J3_4" to="32" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J3_5" to="39" fromLane="0" toLane="0" via=":J3_13_0" dir="l" state="m"/>
    <connection from=":J3_13" to="39" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J3_6" to="310" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J3_7" to="36" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J3_8" to="32" fromLane="0" toLane="0" via=":J3_14_0" dir="l" state="m"/>
    <connection from=":J3_14" to="32" fromLane="0" toLane="0" dir="l" state="M"/>
    <connection from=":J3_9" to="39" fromLane="0" toLane="0" dir="r" state="M"/>
    <connection from=":J3_10" to="310" fromLane="0" toLane="0" dir="s" state="M"/>
    <connection from=":J3_11" to="36" fromLane="0" toLane="0" via=":J3_15_0" dir="l" state="m"/>
    <connection from=":J3_15" to="36" fromLane="0" toLane="0" dir="l" state="M"/>

</net>

    """

    
    #read route file (randomly  generated)
    ! python3 {PATH}/randomTrips.py \
    -n {sim_net} \
    -r {prefix}.rou.xml \
    -e 100 \
    -s {seed}


    #read route file
    with open(f'{prefix}.rou.xml', 'r') as file:
        # Read the entire content of the file
        rou_xml_str = file.read()


    
    #write to .net.xml file for the green time 
    with open(f'3intersections_{prefix}.net.xml', "w") as net_xml_file:
        net_xml_file.write(net_str)



    
    #write to .sumo.cfg file
    
    cfg_file_name=f'config{green_time}s.sumo.cfg'
    config_file_dir=os.path.join(new_dir,cfg_file_name)
    
    with open(config_file_dir, "w") as sumo_config_file:
        sumo_config_file.write(cfg_str)
    
    #write to additionalxs.xmml file
    
    add_file_name=f'additional{green_time}s.xml'
    add_file_dir=os.path.join(new_dir,add_file_name)
    
    with open(add_file_dir, "w") as add_file:
        add_file.write(add_str)
    
    #write to .rou.xml file (same for all green times)
    
    rou_xml_name=f'routetrips{numVeh}cars.rou.xml'
    rou_file_dir=os.path.join(new_dir,rou_xml_name)
    
    with open(rou_file_dir, "w") as rou_file:
        rou_file.write(rou_xml_str)
    
    print(config_file_dir)
    
    #run sumo
    # !sumo -c {config_file_dir}
