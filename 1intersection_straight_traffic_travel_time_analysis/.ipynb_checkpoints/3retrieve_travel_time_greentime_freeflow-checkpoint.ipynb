# %%
import xml.etree.ElementTree as ET
import csv
import os
import pandas as pd

#numVeh=100

# %%
for numVeh in range(1000,1001,100):
    
    summary_all_travel_times=pd.DataFrame()
    
    #make new directory for output /output_mean_travel_time
    new_dir=f'./data/{numVeh}vehicles/output_mean_travel_time'
    os.makedirs(new_dir,exist_ok=True)
    
    
    for green_time in range(20,60,1): #20-60
        
        for speed_limit in range(10,11,1): #10-50

            freeflow_travel_time=speed_limit
        
            # Load and parse the XML file
            file_path=f'data/{numVeh}vehicles/green{green_time}s/freeflow{freeflow_travel_time}s/fcd_output.xml'
            # Parse the XML file
            tree = ET.parse(file_path)
            root = tree.getroot()
            
            # Initialize a dictionary to store the time spent on each lane by each vehicle
            vehicle_lane_times = {}
            
            # Iterate over each timestep in the XML
            for timestep in root.findall('timestep'):
                time = float(timestep.get('time'))
                for vehicle in timestep.findall('vehicle'):
                    vehicle_id = vehicle.get('id')
                    lane_id = vehicle.get('lane')
                    
                    if vehicle_id not in vehicle_lane_times:
                        vehicle_lane_times[vehicle_id] = {}
                    if lane_id not in vehicle_lane_times[vehicle_id]:
                        vehicle_lane_times[vehicle_id][lane_id] = 0
                    
                    vehicle_lane_times[vehicle_id][lane_id] += 1  # Assuming each timestep is 1 second
            
            # Convert the dictionary to a DataFrame
            data = []
            for vehicle_id, lanes in vehicle_lane_times.items():
                for lane_id, time_spent in lanes.items():
                    data.append([vehicle_id, lane_id, time_spent])
            
            df = pd.DataFrame(data, columns=['Vehicle_ID', 'Lane_ID', 'Time_Spent'])
    
            # Filter out rows where Lane_ID starts with ":"
            filtered_df = df[~df['Lane_ID'].str.startswith(':')]
            
            # Calculate the average time spent on each Lane_ID, averaged over the number of vehicles on the lanes
            average_time_travel = filtered_df.groupby('Lane_ID').apply(lambda x: x['Time_Spent'].sum() / x['Vehicle_ID'].nunique()).reset_index()
            
            # Rename the columns for clarity
            average_time_travel.columns = ['Lane_ID', 'Average_Time_Spent']

            #adding the green time and freeflow_travel_time
            average_time_travel['green_time']=green_time
    
            average_time_travel['freeflow_travel_time']=freeflow_travel_time
    
            summary_all_travel_times=pd.concat([summary_all_travel_times,average_time_travel],ignore_index=True)
        
        
    
        
    
    print(f"number of vehicle  = {numVeh}, summary_all_travel_times")
    
    print(summary_all_travel_times)
    
    #save summary as csv with all travel times of different green times 
    summary_all_travel_times.to_csv(f'./data/{numVeh}vehicles/output_mean_travel_time/{numVeh}cars_summary_mean_travel_time.csv',index=False)
# Out:
# green time = 5, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           43.740556           5
# 1       10           41.514444           5
# 2       12           88.659500           5
# 3       13           77.081034           5
# 4       14           79.953448           5
# 5       21           95.045789           5
# 6       31         4252.828333           5
# 7       41         4248.747000           5
# green time = 6, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           44.076111           6
# 1       10           41.495556           6
# 2       12           88.631500           6
# 3       13           77.165517           6
# 4       14           78.747241           6
# 5       21          103.907895           6
# 6       31         3238.451333           6
# 7       41         3282.943333           6
# green time = 7, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           44.186111           7
# 1       10           41.808333           7
# 2       12           88.614500           7
# 3       13           78.255172           7
# 4       14           80.124138           7
# 5       21           96.370526           7
# 6       31         2816.180667           7
# 7       41         2809.963667           7
# green time = 8, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           44.436667           8
# 1       10           41.918889           8
# 2       12           88.498000           8
# 3       13           78.167241           8
# 4       14           81.221724           8
# 5       21           99.904737           8
# 6       31         2467.000667           8
# 7       41         2484.012333           8
# green time = 9, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           44.604444           9
# 1       10           41.888889           9
# 2       12           88.515500           9
# 3       13           78.738621           9
# 4       14           81.028966           9
# 5       21          105.108421           9
# 6       31         2091.061000           9
# 7       41         2087.046333           9
# green time = 10, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           44.852222          10
# 1       10           41.511667          10
# 2       12           88.543000          10
# 3       13           79.197241          10
# 4       14           81.040690          10
# 5       21          111.723158          10
# 6       31         1858.248333          10
# 7       41         1860.142667          10
# green time = 11, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           45.112222          11
# 1       10           41.149474          11
# 2       12           88.613500          11
# 3       13           78.430000          11
# 4       14           80.788276          11
# 5       21          114.054737          11
# 6       31         1659.915667          11
# 7       41         1655.836333          11
# green time = 12, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           45.220556          12
# 1       10           41.846316          12
# 2       12           88.573000          12
# 3       13           80.395172          12
# 4       14           79.762759          12
# 5       21          121.011579          12
# 6       31         1435.206000          12
# 7       41         1503.853000          12
# green time = 13, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           45.501111          13
# 1       10           41.671053          13
# 2       12           88.661500          13
# 3       13           79.768966          13
# 4       14           81.397241          13
# 5       21          126.441053          13
# 6       31         1307.681667          13
# 7       41         1339.284000          13
# green time = 14, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           45.802222          14
# 1       10           41.667368          14
# 2       12           88.658500          14
# 3       13           82.127931          14
# 4       14           80.526897          14
# 5       21          131.024211          14
# 6       31         1193.070333          14
# 7       41         1174.188000          14
# green time = 15, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           46.178333          15
# 1       10           41.644737          15
# 2       12           88.651000          15
# 3       13           81.025517          15
# 4       14           82.538276          15
# 5       21          127.825789          15
# 6       31         1130.985333          15
# 7       41         1146.332667          15
# green time = 16, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           46.708889          16
# 1       10           41.649474          16
# 2       12           88.629000          16
# 3       13           81.565517          16
# 4       14           81.535172          16
# 5       21          128.266316          16
# 6       31         1017.640000          16
# 7       41          997.807333          16
# green time = 17, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           47.447222          17
# 1       10           41.692105          17
# 2       12           88.636500          17
# 3       13           81.428621          17
# 4       14           81.920345          17
# 5       21          139.420000          17
# 6       31          933.369333          17
# 7       41          970.720667          17
# green time = 18, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           47.807778          18
# 1       10           41.997895          18
# 2       12           88.666500          18
# 3       13           82.068621          18
# 4       14           82.290000          18
# 5       21          133.424737          18
# 6       31          870.511000          18
# 7       41          883.746667          18
# green time = 19, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           48.215000          19
# 1       10           41.927895          19
# 2       12           88.992000          19
# 3       13           82.277241          19
# 4       14           83.298966          19
# 5       21          128.969474          19
# 6       31          818.837667          19
# 7       41          842.555333          19
# green time = 20, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           48.821111          20
# 1       10           41.661053          20
# 2       12           88.951500          20
# 3       13           81.622414          20
# 4       14           83.285517          20
# 5       21          141.211053          20
# 6       31          772.220000          20
# 7       41          764.667000          20
# green time = 21, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           49.472222          21
# 1       10           42.024211          21
# 2       12           88.886000          21
# 3       13           81.772069          21
# 4       14           84.678966          21
# 5       21          126.600526          21
# 6       31          729.903000          21
# 7       41          727.361333          21
# green time = 22, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           50.077778          22
# 1       10           41.835789          22
# 2       12           89.107500          22
# 3       13           83.126207          22
# 4       14           84.049310          22
# 5       21          139.960000          22
# 6       31          683.147667          22
# 7       41          679.993000          22
# green time = 23, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           50.673889          23
# 1       10           41.840000          23
# 2       12           89.091500          23
# 3       13           82.962759          23
# 4       14           82.472759          23
# 5       21          138.034737          23
# 6       31          641.120333          23
# 7       41          640.067000          23
# green time = 24, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           51.471111          24
# 1       10           41.863158          24
# 2       12           89.184500          24
# 3       13           84.231724          24
# 4       14           83.317586          24
# 5       21          147.665263          24
# 6       31          618.610667          24
# 7       41          609.626000          24
# green time = 25, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           52.293889          25
# 1       10           42.134737          25
# 2       12           89.280500          25
# 3       13           83.223103          25
# 4       14           84.933448          25
# 5       21          128.710000          25
# 6       31          588.866667          25
# 7       41          594.981333          25
# green time = 26, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           53.184444          26
# 1       10           41.803158          26
# 2       12           89.308500          26
# 3       13           84.583448          26
# 4       14           85.234828          26
# 5       21          141.453158          26
# 6       31          586.405000          26
# 7       41          607.121000          26
# green time = 27, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           53.853889          27
# 1       10           41.881053          27
# 2       12           89.455500          27
# 3       13           85.209310          27
# 4       14           85.347586          27
# 5       21          158.075789          27
# 6       31          519.988966          27
# 7       41          517.356552          27
# green time = 28, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           54.737222          28
# 1       10           42.020526          28
# 2       12           89.572000          28
# 3       13           86.426207          28
# 4       14           85.486207          28
# 5       21          147.417895          28
# 6       31          548.863448          28
# 7       41         1495.550690          28
# green time = 29, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           55.551667          29
# 1       10           42.004737          29
# 2       12           89.605000          29
# 3       13           83.965714          29
# 4       14           86.303571          29
# 5       21          146.096316          29
# 6       31          463.511071          29
# 7       41          463.628214          29
# green time = 30, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           56.503889          30
# 1       10           41.927368          30
# 2       12           89.935000          30
# 3       13           85.706667          30
# 4       14           84.082143          30
# 5       21          144.434211          30
# 6       31          484.015714          30
# 7       41          411.129615          30
# green time = 31, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           57.936667          31
# 1       10           42.030526          31
# 2       12           89.802000          31
# 3       13           85.069259          31
# 4       14           85.191852          31
# 5       21          151.686316          31
# 6       31          421.444231          31
# 7       41          461.820769          31
# green time = 32, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           58.522222          32
# 1       10           42.130000          32
# 2       12           90.132000          32
# 3       13           86.278846          32
# 4       14           85.705769          32
# 5       21          158.274211          32
# 6       31          357.950000          32
# 7       41          352.378000          32
# green time = 33, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           59.483889          33
# 1       10           42.095789          33
# 2       12           89.993000          33
# 3       13           86.484615          33
# 4       14           84.880000          33
# 5       21          165.552105          33
# 6       31          350.632400          33
# 7       41          339.063600          33
# green time = 34, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           60.540556          34
# 1       10           42.303684          34
# 2       12           90.098500          34
# 3       13           85.130833          34
# 4       14           86.268333          34
# 5       21          173.670526          34
# 6       31          302.305833          34
# 7       41          296.763750          34
# green time = 35, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           61.880556          35
# 1       10           42.176316          35
# 2       12           90.085000          35
# 3       13           85.959583          35
# 4       14           85.727500          35
# 5       21          182.298421          35
# 6       31          311.344783          35
# 7       41          308.656957          35
# green time = 36, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           63.288889          36
# 1       10           42.216842          36
# 2       12           89.865500          36
# 3       13           86.854167          36
# 4       14           84.805417          36
# 5       21          177.995263          36
# 6       31          418.653913          36
# 7       41          412.793913          36
# green time = 37, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           64.187222          37
# 1       10           42.550000          37
# 2       12           89.897000          37
# 3       13           86.449130          37
# 4       14           86.517826          37
# 5       21          185.707895          37
# 6       31          245.578636          37
# 7       41          230.825000          37
# green time = 38, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           65.375000          38
# 1       10           42.376842          38
# 2       12           89.945000          38
# 3       13           85.569545          38
# 4       14           87.529545          38
# 5       21          168.997368          38
# 6       31          233.404545          38
# 7       41          224.907273          38
# green time = 39, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           66.538889          39
# 1       10           42.289474          39
# 2       12           89.890000          39
# 3       13           87.263333          39
# 4       14           86.828182          39
# 5       21          184.470000          39
# 6       31          218.170455          39
# 7       41          194.562857          39
# green time = 40, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           70.702222          40
# 1       10           42.394737          40
# 2       12           89.158000          40
# 3       13           86.714762          40
# 4       14           85.979524          40
# 5       21          177.947895          40
# 6       31          192.983333          40
# 7       41          192.437619          40
# green time = 41, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           75.117778          41
# 1       10           42.543684          41
# 2       12           89.049000          41
# 3       13           86.094762          41
# 4       14           86.276667          41
# 5       21          163.936842          41
# 6       31          210.644500          41
# 7       41          205.103000          41
# green time = 42, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1           87.860556          42
# 1       10           42.540000          42
# 2       12           88.395500          42
# 3       13           86.827619          42
# 4       14           86.503333          42
# 5       21          168.669474          42
# 6       31          274.142500          42
# 7       41          327.639500          42
# green time = 43, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          151.404737          43
# 1       10           42.357368          43
# 2       12           88.550476          43
# 3       13           86.746000          43
# 4       14           87.000500          43
# 5       21          151.502632          43
# 6       31          135.704211          43
# 7       41          132.604211          43
# green time = 44, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          119.699000          44
# 1       10           42.479474          44
# 2       12           87.834286          44
# 3       13           87.852500          44
# 4       14           87.175500          44
# 5       21          153.261500          44
# 6       31          125.927895          44
# 7       41          122.478947          44
# green time = 45, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          124.438000          45
# 1       10           41.752500          45
# 2       12           88.862857          45
# 3       13           88.063500          45
# 4       14           87.464500          45
# 5       21          168.187500          45
# 6       31          117.915789          45
# 7       41          120.448947          45
# green time = 46, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          134.052000          46
# 1       10           41.819524          46
# 2       12           88.363636          46
# 3       13           88.313500          46
# 4       14           88.278000          46
# 5       21          244.470952          46
# 6       31          114.590526          46
# 7       41          116.111579          46
# green time = 47, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          175.870000          47
# 1       10           41.897619          47
# 2       12           87.671304          47
# 3       13           88.283000          47
# 4       14           88.883000          47
# 5       21          224.900476          47
# 6       31          114.024211          47
# 7       41          114.534211          47
# green time = 48, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          168.872857          48
# 1       10           42.754762          48
# 2       12           89.720000          48
# 3       13           88.648500          48
# 4       14           89.001500          48
# 5       21          230.003333          48
# 6       31          113.288421          48
# 7       41          113.380000          48
# green time = 49, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          172.705238          49
# 1       10           42.185909          49
# 2       12           89.751304          49
# 3       13           88.669000          49
# 4       14           88.944500          49
# 5       21          310.396818          49
# 6       31          113.120526          49
# 7       41          112.730000          49
# green time = 50, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          205.708261          50
# 1       10           41.686818          50
# 2       12           88.776667          50
# 3       13           88.590000          50
# 4       14           88.647500          50
# 5       21          272.074348          50
# 6       31          111.833684          50
# 7       41          112.108947          50
# green time = 51, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          200.265652          51
# 1       10           41.379565          51
# 2       12           88.749200          51
# 3       13           87.596500          51
# 4       14           88.072500          51
# 5       21          283.978696          51
# 6       31          111.443684          51
# 7       41          109.736842          51
# green time = 52, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          205.007826          52
# 1       10           41.897083          52
# 2       12           91.309200          52
# 3       13           87.532000          52
# 4       14           88.482500          52
# 5       21          382.132083          52
# 6       31          110.372105          52
# 7       41          108.584211          52
# green time = 53, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          233.069167          53
# 1       10           41.648750          53
# 2       12           90.938462          53
# 3       13           87.103000          53
# 4       14           88.258500          53
# 5       21          343.450417          53
# 6       31          110.220526          53
# 7       41          108.491579          53
# green time = 54, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          233.763750          54
# 1       10           42.006800          54
# 2       12           90.938462          54
# 3       13           87.281500          54
# 4       14           88.555500          54
# 5       21          407.736538          54
# 6       31          109.302105          54
# 7       41          106.607368          54
# green time = 55, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          254.959231          55
# 1       10           41.529231          55
# 2       12           88.768077          55
# 3       13           87.129000          55
# 4       14           88.050500          55
# 5       21          392.452692          55
# 6       31          109.449474          55
# 7       41          104.738947          55
# green time = 56, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          770.186296          56
# 1       10           41.102222          56
# 2       12           87.848214          56
# 3       13           87.352000          56
# 4       14           89.095000          56
# 5       21          473.855185          56
# 6       31          108.472632          56
# 7       41          104.315263          56
# green time = 57, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          294.912593          57
# 1       10           40.954444          57
# 2       12           89.186071          57
# 3       13           86.850500          57
# 4       14           88.421500          57
# 5       21          449.563704          57
# 6       31          109.032105          57
# 7       41          103.044737          57
# green time = 58, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          397.541724          58
# 1       10           41.271429          58
# 2       12           87.617241          58
# 3       13           86.789500          58
# 4       14           88.412105          58
# 5       21          498.703103          58
# 6       31          107.893158          58
# 7       41          102.018947          58
# green time = 59, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          309.064483          59
# 1       10           41.600690          59
# 2       12           87.815862          59
# 3       13           86.949500          59
# 4       14           88.565789          59
# 5       21          506.100690          59
# 6       31          107.069474          59
# 7       41          101.658947          59
# green time = 60, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          360.424333          60
# 1       10           41.264483          60
# 2       12           88.065172          60
# 3       13           86.896000          60
# 4       14           88.494211          60
# 5       21          556.652000          60
# 6       31          106.945263          60
# 7       41          101.142105          60
# green time = 61, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          341.045000          61
# 1       10           41.355862          61
# 2       12           89.003448          61
# 3       13           86.953000          61
# 4       14           88.628421          61
# 5       21          604.116667          61
# 6       31          106.881579          61
# 7       41          100.189474          61
# green time = 62, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          368.046667          62
# 1       10           41.285862          62
# 2       12           87.287586          62
# 3       13           86.910000          62
# 4       14           88.441053          62
# 5       21          627.671333          62
# 6       31          106.117895          62
# 7       41           99.906316          62
# green time = 63, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          385.064333          63
# 1       10           41.418276          63
# 2       12           88.318621          63
# 3       13           86.919000          63
# 4       14           88.552105          63
# 5       21          660.798667          63
# 6       31          105.303158          63
# 7       41           99.278947          63
# green time = 64, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          407.213333          64
# 1       10           41.552069          64
# 2       12           84.856552          64
# 3       13           86.027000          64
# 4       14           88.507895          64
# 5       21          702.289667          64
# 6       31          105.348421          64
# 7       41           99.022105          64
# green time = 65, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          427.247333          65
# 1       10           41.176207          65
# 2       12           87.304138          65
# 3       13           86.049000          65
# 4       14           88.471053          65
# 5       21          723.409000          65
# 6       31          105.177895          65
# 7       41           97.563684          65
# green time = 66, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          440.879000          66
# 1       10           41.300690          66
# 2       12           86.481379          66
# 3       13           86.223000          66
# 4       14           88.493684          66
# 5       21          777.262333          66
# 6       31          104.100526          66
# 7       41           96.700526          66
# green time = 67, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          491.230333          67
# 1       10           41.168276          67
# 2       12           84.276552          67
# 3       13           85.861500          67
# 4       14           88.720000          67
# 5       21          834.744667          67
# 6       31          103.702632          67
# 7       41           96.068947          67
# green time = 68, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          506.276000          68
# 1       10           40.387586          68
# 2       12           86.465862          68
# 3       13           86.123500          68
# 4       14           87.726316          68
# 5       21          893.326000          68
# 6       31          103.575263          68
# 7       41           95.908421          68
# green time = 69, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          562.523333          69
# 1       10           40.367586          69
# 2       12           84.847241          69
# 3       13           86.204000          69
# 4       14           87.643158          69
# 5       21          965.876333          69
# 6       31          103.881053          69
# 7       41           94.504737          69
# green time = 70, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          585.023667          70
# 1       10           40.243793          70
# 2       12           85.432069          70
# 3       13           86.360500          70
# 4       14           87.969474          70
# 5       21         1019.351333          70
# 6       31          103.095789          70
# 7       41           92.967368          70
# green time = 71, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          662.940000          71
# 1       10           40.635517          71
# 2       12           85.894828          71
# 3       13           86.455500          71
# 4       14           86.437368          71
# 5       21         1132.457667          71
# 6       31          103.081053          71
# 7       41           92.687895          71
# green time = 72, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          699.138667          72
# 1       10           40.407241          72
# 2       12           84.465862          72
# 3       13           86.622000          72
# 4       14           86.578421          72
# 5       21         1222.862333          72
# 6       31          104.713158          72
# 7       41           91.325789          72
# green time = 73, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          786.715333          73
# 1       10           39.945517          73
# 2       12           82.938276          73
# 3       13           86.406000          73
# 4       14           86.662105          73
# 5       21         1393.730333          73
# 6       31          102.655789          73
# 7       41           91.022632          73
# green time = 74, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          861.198000          74
# 1       10           40.297586          74
# 2       12           83.476552          74
# 3       13           85.408500          74
# 4       14           86.678947          74
# 5       21         1386.738000          74
# 6       31          102.488421          74
# 7       41           89.095789          74
# green time = 75, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1          978.393000          75
# 1       10           39.944828          75
# 2       12           82.895862          75
# 3       13           85.505000          75
# 4       14           86.497895          75
# 5       21         1674.994667          75
# 6       31          101.083158          75
# 7       41           88.225263          75
# green time = 76, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         1140.119000          76
# 1       10           39.268276          76
# 2       12           80.650345          76
# 3       13           85.641000          76
# 4       14           86.624737          76
# 5       21         1851.146333          76
# 6       31          102.535789          76
# 7       41           87.701579          76
# green time = 77, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         1222.769000          77
# 1       10           39.136207          77
# 2       12           80.310690          77
# 3       13           85.750500          77
# 4       14           86.980526          77
# 5       21         2112.229333          77
# 6       31          100.500000          77
# 7       41           87.322105          77
# green time = 78, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         1384.340333          78
# 1       10           39.388621          78
# 2       12           81.100690          78
# 3       13           85.978000          78
# 4       14           86.854211          78
# 5       21         2448.206667          78
# 6       31          101.314211          78
# 7       41           86.959474          78
# green time = 79, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         1648.501667          79
# 1       10           39.480000          79
# 2       12           80.120345          79
# 3       13           86.060500          79
# 4       14           86.713684          79
# 5       21         2836.210333          79
# 6       31          102.725263          79
# 7       41           85.989474          79
# green time = 80, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         1980.531333          80
# 1       10           39.645172          80
# 2       12           78.998276          80
# 3       13           86.357500          80
# 4       14           86.852632          80
# 5       21         3281.850667          80
# 6       31          101.082105          80
# 7       41           85.961579          80
# green time = 81, average_travel_times
#    edge_id  average_traveltime  green_time
# 0        1         2493.499667          81
# 1       10           39.244828          81
# 2       12           77.949655          81
# 3       13           86.523000          81
# 4       14           86.822632          81
# 5       21         4269.675000          81
# 6       31          101.223158          81
# 7       41           85.592105          81
# number of vehicle  = 1000, summary_all_travel_times
#      edge_id  average_traveltime  green_time
# 0          1           43.740556           5
# 1         10           41.514444           5
# 2         12           88.659500           5
# 3         13           77.081034           5
# 4         14           79.953448           5
# ..       ...                 ...         ...
# 611       13           86.523000          81
# 612       14           86.822632          81
# 613       21         4269.675000          81
# 614       31          101.223158          81
# 615       41           85.592105          81
#
# [616 rows x 3 columns]
